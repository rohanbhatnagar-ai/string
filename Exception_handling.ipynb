# %%
# what is exception handling?
# an exception is an error that occur during program executions (runtime) --not before it runs

# %%
# value error
A = int(input("enter thr valur"))
# Out:
# enter thr valur 23

# %%
# type error
B = input("enter thr valur")
A +B
# Out:
# enter thr valur 34
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # type error
#       2 B = input("enter thr valur")
# ----> 3 A +B
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# index error
list1 = [1,3,3]
lists[50]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # index error
#       2 list1 = [1,3,3]
# ----> 3 lists[50]
#
# NameError: name 'lists' is not defined

# %%
# synatax error
try:
    # block of code
    except exceptiontype:
    # error msg

# %%
try:
    a = 2.3
    b = "sumit"
    c = a+b
    print(c)

except TypeError:
    print("both type valur should be same")
# Out:
# both type valur should be same

# %%
try:
    a = [1,2,3,4,5]
    b = "sumit"
    c = a+b
    print(c)

except IndexError:
    print("both type indexer should be same")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2     a = [1,2,3,4,5]
#       3     b = "sumit"
# ----> 4     c = a+b
#       5     print(c)
#       7 except IndexError:
#
# TypeError: can only concatenate list (not "str") to list

# %%
try:
    a ="sumit"
    b = 20
    c = A + y
    print(c)
except Exception(nameerror,typeerror) :
    print(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       3 b = 20
# ----> 4 c = A + y
#       5 print(c)
#
# NameError: name 'y' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       4     c = A + y
#       5     print(c)
# ----> 6 except Exception(nameerror,typeerror) :
#       7     print(e)
#
# NameError: name 'nameerror' is not defined

# %%
# try except else:
try:
    user_id = input("enter user Id")
    password = input("enter the password")

    if user_id == "sumit@4952" and password== "admin":
        print("user name and password is matched")
except Exception as e:
    print(e)
else:
    print("login sucessfully")
# Out:
# enter user Id sumit@4952
# enter the password admin
# user name and password is matched
# login sucessfully

# %%
# try except else finlly
try:
    a = 20
    b = "sumit"
    c = a+b 
    print(c)
except Exception as e:
    print(e)
else:
    print(c)
finally:
    print("all process done")
# Out:
# unsupported operand type(s) for +: 'int' and 'str'
# all process done

# %%
# create the function using try except
#try'
#take value from user side
# create function even or odd
# except:
#error the msg
#finally:
#program executed sucessfully
try:
    num = int(input("enter the user no"))
    if num%2==0:
        print(f"even{num}")
except Exception as e:
    print(e)
else:
    print(f"odd{num}")
finally:
    print("prgram executed sucessfullye")
# Out:
# enter the user no 7
# odd7
# prgram executed sucessfullye
