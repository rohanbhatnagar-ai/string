# %%
# Q1. Positive Number

# Take a number from the user and check whether it is positive.
num =int( input("enter the user"))
if num>0:
    print("positive:")
else:
    print("Negative")
# Out:
# enter the user 12
# positive:

# %%
# Q2. Pass or Fail

# Take marks from the user.

# Marks >= 40 → Pass
# Marks < 40 → Fail
marks = int(input("enter the user"))
if marks>=40:

    print("Pass")
else:
    print("Fail")
# Out:
# enter the user 88
# Pass

# %%
# Q3. Age Check

# Take age.

# Age >= 18 → Eligible
# Otherwise → Not Eligible
age = int(input("enter your age"))
if age>=18:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# enter your age 78
# Eligible

# %%
# Q4. Number Between 1 and 100

# Check whether a number is between 1 and 100, including both.
num = int(input("enter the"))
if
