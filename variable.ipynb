# %%
# types of oops
# type 1 encapsulation


class Class_name:
    # constructor
    def __init__(self,args):
        self .variable_name:args

        # accessor
        def get_private_attribute_name(self): # access the private attribute data
            return(self._variable_name)

         # setter
        def set_private_attribute_name(self):
            # block of code
# Out:
#   Cell In[2], line 16
#     # block of code
#                    ^
# _IncompleteInputError: incomplete input

# %%
# without encapsulation
class Bank_account:
    # constructor:
    def __init__(self,owner,bal):
        # create the attributes
        self.Owner_name= owner
        self._bank_balance = bal
        # getter : access the private attributes:
    def get_balance(self):
         return self.__bank_balance
        # setter ;set_validation always apply the condition in private
    def deposite(self,amt):
         if amt > 0:
            self.__bank_balance += amt

            return self.__bank_balance
         else:
             return "Please enter the valid result"
        
        # method 1
    def disply_bank_details(self):
        print(f"onwer name:{self.owner_name}")
        print(f"bank balance:{self.bal}")

    # create the class oject
    bank1 = Bank_account("sumit",200)

    # call the method
   # bank1.display_bank_details()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # without encapsulation
# ----> 2 class Bank_account:
#       3     # constructor:
#       4     def __init__(self,owner,bal):
#       5         # create the attributes
#       6         self.Owner_name= owner
#
# Cell In[19], line 26, in Bank_account()
#      23     print(f"bank balance:{self.bal}")
#      25 # create the class oject
# ---> 26 bank1 = Bank_account("sumit",200)
#      27 print(bank1.owner_name)
#
# NameError: name 'Bank_account' is not defined

# %%
# ttpe 2" abstraction 
from abc import ABC, abstractmethod
class Class_name(ABC):


    # abstract method
    @abstractmethod


    def sound(self):
        pass

# %%
# without c
class Cat:
    def sound(self):
        print("mwowwwww!")
class Dog :
    def sound(self):
        print("bhaiuuuuuu!)
class Cow :
    def sound(self):
        print("cdada")

# %%
# with absraction
class Animals(ABC):
    # abstract :
    @abstractmethod
    def sound(self):
        pass

# child class
class Cat(Animals):
    def sound(self):
        print("mewoooo!)
 #child class
class Dog (Animals):
              
    def sound(self):
        print("mewoooo!)
class Cow(Animals):
    def sound(self):
        print("mewoooo!)
    # create the class object
cat = Cat()
dog =Dog()
cow = Cow()
cat.sound()
# Out:
#   Cell In[27], line 11
#     print("mewoooo!)
#           ^
# SyntaxError: unterminated string literal (detected at line 11)

# %%
# food management
class Food(ABC):
    
     # constructor:
    def __init__(self,f_name,f_price):
        self.__Food_name = f_name
        self.__food_price = f_price
     # getter name
    def get_food_name(self):
        return self.__Food_name
    # getter price
    def self.__Food_price(self):
     return self.__Food_price
     # abstract method
     @ abstractmethod
    def prepare(self):
        pass
    # abstract method
    @ abstractmethod
    def deliver(self):
       pass
    # display all destails
    def display_all_details(self):
         print(f"Food Name :{self.get_food_name}")
         print(f"Food Price :{self.get_food_price}")
         self.prepare()
         self.deliver()
# child class
class Pizza(Food):

    def prepare(self):
        print("pizza is prepare")
    def deliver(self):
        print("pizza is deliverd")
# child class
class Burger(Food):

    def prepare(self):
        print("Burger is prepare")
    def deliver(self):
        print("Burger is deliverd")
#  2 child class
class Biriyani(Food):

    def prepare(self):
        print("Biriyani is prepare")
    def deliver(self):
        print("Biriyani is deliverd")
# create the object
pizza = Pizza("Pizza",500)
Biriyani = Biriyani("Biriyani",600)
Burger = Burger("Burger",700)



pizza.get_food_name()
burger.get_food_name()
biriyani.get_food_name()
# Out:
#   Cell In[36], line 12
#     def self.__Food_price(self):
#             ^
# SyntaxError: expected '('

# %%
# take the parent : company
# take two args : name, desg
# get the private data
# make two abstact methods:
# 1 : work 
# 2 : salary
# display all info
#name, role,work,salary
# create the two child class : employee, Manager
class Company:
    # constructor
    def __init__(self,name,desn):
        self.names = name
        self.design = desn
        # getter
    def get_names(self):
        return self.get_names
        # setter
        def self.desn(self):
        return self.__set_desn

         @ abstractmethod
    def prepare(self):
        pass
    # abstract method
    @ abstractmethod
    def deliver(self):
         pass
    # display all destails
    def display_all_details(self):
         print(f"get Name :{self.get_names}")
         print(f"get design :{self.get_desn}")
         self.prepare()
         self.deliver()

#child class
class Work(Company):

    def prepare(self):
        print("getting name")
    def deliver(self):
        print("design")
Name = Name("Sumit",500)

Name.get_name()
# Out:
#   Cell In[41], line 19
#     def self.desn(self):
#             ^
# SyntaxError: expected '('
